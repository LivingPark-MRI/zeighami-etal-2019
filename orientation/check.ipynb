# %%
import nibabel as nib
import os
import glob
import pandas as pd
import nilearn.plotting as nilp
from matplotlib import pyplot as plt
import numpy as np
from boutiques import descriptor2func as fun

pd.set_option("display.max_rows", None)

# %%
# Read QC file from experiments 1 and 2
qc_df = pd.read_csv(
    "status-4554467823934740347_nlr4_dbm8_from_nifti_old_pipeline_qc.csv"
)
subj_ids = qc_df["subject"].to_numpy()

# Check that we get the same number of subject as in the paper
assert len(subj_ids) == 344

# Filter subjects that passed QC for exp 1 and 2
subj_ids_pass = qc_df[qc_df["pipeline_complete"] == "SUCCESS"]["subject"].to_numpy()
assert len(subj_ids_pass) == 306

# %%
# The mnc files in mincignore.csv need to be ignored as they were not involved in the experiment
# It is because some subjects had more than one T1 in the same session.
# When that happened Michelle looked at the T1s on LONI and chose one to keep. The paths to the T1s that were not used are in mincignore.csv
with open(os.path.join("input", "mincignore.csv")) as f:
    ignored_files = f.readlines()
ignored_files = [
    x.replace("/data/origami/livingpark/zeighami-etal-2019/dbm/", "").replace("\n", "")
    for x in ignored_files
]

# %%
def get_mincs(subj_id):
    """
    Return (minc_file, minc_from_nifti_file) for subject id. Minc_file
    is the path to the MINC file converted from DICOM whereas minc_from_nifti_file
    is the path to the MINC file converted from Nifti.
    """

    def file_in_dir(dirname):
        if not os.path.exists(dirname):
            print(f"Warning: missing directory: {dirname}")
            return None
        g = [x for x in glob.glob(os.path.join(dirname, "*")) if x not in ignored_files]
        if len(g) == 0:
            raise Exception(f"Empty directory: {dirname}")
        if len(g) != 1:
            raise Exception(f"Found directory with more than 1 file: {dirname}")
        return g[0]

    # For this subject there's multiple minc files converted from nifti
    # Michelle said Nikhil said that the DICOM to Nifti conversion might have been
    # bad and that we should use the *_T1w1* file
    if subj_id == 3869:
        return (
            "input/minc/3869/1/557573.mnc",
            "input/minc_from_nifti/3869/1/sub-3869_ses-1_acq-grappa2_run-05_T1w1.mnc",
        )

    minc_file = file_in_dir(os.path.join("input", "minc", str(subj_id), "1"))
    minc_from_nifti_file = file_in_dir(
        os.path.join("input", "minc_from_nifti", str(subj_id), "1")
    )

    return minc_file, minc_from_nifti_file

# %%
def get_shape(minc_file):
    """
    Get the shape of the image in minc_file
    """
    if minc_file is None:
        return None
    try:
        im = nib.load(minc_file)
    except ValueError as e:
        print(f"Warning: cannot read MINC file {minc_file}: {e}")
        return None
    return im.header.get_data_shape()


def get_type(minc_file):
    """
    Get the data type of the image in minc_file
    """
    if minc_file is None:
        return None
    try:
        im = nib.load(minc_file)
    except ValueError as e:
        print(f"Warning: cannot read MINC file {minc_file}: {e}")
        return None
    return im.header.get_data_dtype()

# %%
# Create a dataframe with the following columns
# PATNO: patient identifier
# minc_files: (minc_file, minc_file_from_nifti) as returned by function get_mincs
# shape1: shape of minc_file
# shape2: shape of minc_file_from_nifti
# dtype1: data type of minc_file
# dtype2: data type of minc_file_from_nifti
df = pd.DataFrame(
    {
        "PATNO": subj_ids_pass,
        "minc_files": [get_mincs(s) for s in subj_ids_pass],
    }
)
df["shape1"] = df["minc_files"].apply(lambda x: get_shape(x[0]))
df["shape2"] = df["minc_files"].apply(lambda x: get_shape(x[1]))

df["dtype1"] = df["minc_files"].apply(lambda x: get_type(x[0]))
df["dtype2"] = df["minc_files"].apply(lambda x: get_type(x[1]))
# Out:
# Warning: cannot read MINC file input/minc/3016/1/310300.mnc: Irregular spacing not supported
# Warning: cannot read MINC file input/minc/3281/1/301422.mnc: Irregular spacing not supported
# Warning: cannot read MINC file input/minc/3016/1/310300.mnc: Irregular spacing not supported
# Warning: cannot read MINC file input/minc/3281/1/301422.mnc: Irregular spacing not supported

# %%
# Ignore images for which a MINC file couldn't be read by nibabel
df = df[~df["shape1"].isna() & ~df["shape2"].isna()]

# %%
# A few images had unusually low dimensions (x or y or z < 100) compared to the other ones
# Here we verified that these images were filterd by QC in experiment 5 and 6 and 
# were therefore excluded from the study


def filter_fn(row, file_id):
    s = row[f"shape{file_id}"]
    for i in (0, 1, 2):
        if s[i] <= 100:
            return True
    return False


def filter_fn_minc(row):
    return filter_fn(row, 1)


def filter_fn_minc_from_nifti(row):
    return filter_fn(row, 2)


m = df.apply(filter_fn_minc, axis=1)
corrupt_mincs = df[m]["PATNO"].to_numpy()
print(
    f"Found {len(corrupt_mincs)} corrupted MINC files. Note: these files were included in experiments 1 and 2."
)

# verify that corrupt mincs failed qc in exp 5 and 6
qc_exp5_6 = pd.read_csv("status-_460520092359662532_old_pipeline_qc.csv")
for x in corrupt_mincs:
    assert (
        x in qc_exp5_6[qc_exp5_6["pipeline_complete"] == "FAIL"]["subject"].to_numpy()
    ), x

m = df.apply(filter_fn_minc_from_nifti, axis=1)
assert len(df[m]) == 0
print(
    "All images with unusually low dimension were filtered by QC in experiments 5 and 6"
)
# Out:
# Found 2 corrupted MINC files. Note: these files were included in experiments 1 and 2.
# All images with unusually low dimension were filtered by QC in experiments 5 and 6

# %%
# Remove images with unusually low dimension
m = df.apply(filter_fn_minc, axis=1)
df = df[~m]

# %%
def check_reoriented(x):
    """
    x = (minc_file, minc_file_from_nifti)

    This function reorients the MINC file in the second element of x (minc_file_from_nifti) to (hopefully) give it
    the same orientation as the file in the first element of x (minc_file).

    The function also checks that the resulting file is nearly identical to minc_file.
    """
    f1, f2 = x
    print(".", end="")
    i1 = nib.load(f1)
    i2 = nib.load(f2)

    #     # Reorient i2 as i1
    #     Nifti version, doesn't work because nibabel can't write to mnc so
    #     we have to use nii2mnc that changes the orientation back to what it was
    #     # See https://github.com/nipy/nibabel/issues/1010
    #     from nibabel.orientations import ornt_transform
    #     orig_ornt = nib.io_orientation(i2.affine)
    #     targ_ornt = nib.io_orientation(i1.affine)

    #     transform = ornt_transform(orig_ornt, targ_ornt)
    #     i2_orient = i2.as_reoriented(transform)

    # Call mincreshape on f2
    mincreshape = fun.function("10.5281/zenodo.7988259")
    filename = f2.replace("minc_from_nifti", "minc_from_nifti_reorient_minc")
    os.makedirs(os.path.dirname(filename), exist_ok=True)
    out = mincreshape(
        "launch",
        infile=f2,
        outfile_name=filename,
        dimsize="zspace=-1",
        flip_ydirection=True,
        flip_zdirection=True,
        dimorder="xspace,zspace,yspace",
    )
    if out.exit_code != 0:
        print(f"Error running mincreshape: {out.stderr}")
        return None

    # Load the reshaped file and checked that it's nearly identical to minc_file
    i2_orient = nib.load(filename)
    sanity_check = np.all(np.abs(i1.get_fdata() - i2_orient.get_fdata()) < 0.5)

    if sanity_check:
        return filename

    print(f"Sanity check failed for {filename}, trying to flip xdirection too.")

    # Re-run mincreshape, this time with -xdirection
    os.remove(filename)
    out = mincreshape(
        "launch",
        infile=f2,
        outfile_name=filename,
        dimsize="zspace=-1",
        flip_xdirection=True,
        flip_ydirection=True,
        flip_zdirection=True,
        dimorder="xspace,zspace,yspace",
    )
    if out.exit_code != 0:
        print(f"Error running mincreshape: {out.stderr}")
        return None

    # Load the reshaped file and checked that it's nearly identical to minc_file
    i2_orient = nib.load(filename)
    sanity_check = np.all(np.abs(i1.get_fdata() - i2_orient.get_fdata()) < 0.5)

    if sanity_check:
        return filename

    print(f"Sanity check failed again for {filename}, giving up.")
    return None

# %%
df["reoriented"] = df["minc_files"].apply(check_reoriented)
# Out:
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3102/1/sub-3102_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3104/1/sub-3104_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3105/1/sub-3105_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3106/1/sub-3106_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3107/1/sub-3107_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3108/1/sub-3108_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3111/1/sub-3111_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3112/1/sub-3112_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3113/1/sub-3113_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3114/1/sub-3114_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3115/1/sub-3115_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3116/1/sub-3116_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3118/1/sub-3118_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3119/1/sub-3119_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3120/1/sub-3120_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3123/1/sub-3123_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3124/1/sub-3124_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3125/1/sub-3125_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3126/1/sub-3126_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3127/1/sub-3127_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3128/1/sub-3128_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3129/1/sub-3129_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3130/1/sub-3130_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3131/1/sub-3131_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3132/1/sub-3132_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3134/1/sub-3134_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3150/1/sub-3150_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3151/1/sub-3151_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3154/1/sub-3154_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3156/1/sub-3156_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3157/1/sub-3157_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3160/1/sub-3160_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3161/1/sub-3161_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3165/1/sub-3165_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3166/1/sub-3166_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3168/1/sub-3168_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3169/1/sub-3169_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3171/1/sub-3171_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3172/1/sub-3172_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3173/1/sub-3173_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3174/1/sub-3174_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3175/1/sub-3175_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3176/1/sub-3176_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3178/1/sub-3178_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3179/1/sub-3179_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3181/1/sub-3181_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3182/1/sub-3182_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3184/1/sub-3184_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3185/1/sub-3185_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3188/1/sub-3188_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3190/1/sub-3190_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3191/1/sub-3191_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3300/1/sub-3300_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3301/1/sub-3301_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3305/1/sub-3305_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3307/1/sub-3307_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3308/1/sub-3308_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3309/1/sub-3309_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3310/1/sub-3310_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3311/1/sub-3311_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3314/1/sub-3314_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3316/1/sub-3316_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3320/1/sub-3320_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3321/1/sub-3321_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3322/1/sub-3322_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3323/1/sub-3323_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3325/1/sub-3325_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3327/1/sub-3327_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3328/1/sub-3328_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3332/1/sub-3332_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3350/1/sub-3350_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3352/1/sub-3352_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3353/1/sub-3353_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3354/1/sub-3354_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3355/1/sub-3355_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3357/1/sub-3357_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3358/1/sub-3358_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3360/1/sub-3360_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3383/1/sub-3383_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3385/1/sub-3385_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3386/1/sub-3386_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3387/1/sub-3387_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3389/1/sub-3389_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3390/1/sub-3390_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3392/1/sub-3392_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3551/1/sub-3551_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3554/1/sub-3554_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3556/1/sub-3556_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3557/1/sub-3557_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3558/1/sub-3558_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3559/1/sub-3559_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3563/1/sub-3563_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3564/1/sub-3564_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3565/1/sub-3565_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3567/1/sub-3567_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3569/1/sub-3569_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3570/1/sub-3570_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3571/1/sub-3571_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3572/1/sub-3572_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3574/1/sub-3574_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3575/1/sub-3575_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3577/1/sub-3577_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3584/1/sub-3584_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3585/1/sub-3585_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3587/1/sub-3587_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3588/1/sub-3588_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3589/1/sub-3589_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3592/1/sub-3592_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3593/1/sub-3593_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3752/1/sub-3752_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3753/1/sub-3753_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3756/1/sub-3756_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3757/1/sub-3757_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3758/1/sub-3758_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3759/1/sub-3759_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3760/1/sub-3760_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3762/1/sub-3762_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3763/1/sub-3763_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3765/1/sub-3765_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3767/1/sub-3767_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3768/1/sub-3768_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3769/1/sub-3769_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3770/1/sub-3770_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3771/1/sub-3771_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3775/1/sub-3775_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3776/1/sub-3776_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3777/1/sub-3777_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3778/1/sub-3778_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3779/1/sub-3779_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3780/1/sub-3780_ses-1_acq-grappa2_run-02_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3781/1/sub-3781_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3787/1/sub-3787_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3788/1/sub-3788_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3789/1/sub-3789_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3800/1/sub-3800_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3802/1/sub-3802_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3803/1/sub-3803_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3804/1/sub-3804_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3805/1/sub-3805_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3806/1/sub-3806_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3807/1/sub-3807_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3808/1/sub-3808_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3811/1/sub-3811_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3812/1/sub-3812_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3813/1/sub-3813_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3814/1/sub-3814_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3815/1/sub-3815_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3816/1/sub-3816_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3817/1/sub-3817_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3818/1/sub-3818_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3819/1/sub-3819_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3822/1/sub-3822_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3823/1/sub-3823_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3824/1/sub-3824_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3825/1/sub-3825_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3826/1/sub-3826_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3828/1/sub-3828_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3829/1/sub-3829_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3830/1/sub-3830_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3831/1/sub-3831_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3832/1/sub-3832_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3834/1/sub-3834_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3835/1/sub-3835_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3838/1/sub-3838_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3850/1/sub-3850_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3851/1/sub-3851_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3852/1/sub-3852_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3853/1/sub-3853_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3854/1/sub-3854_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3855/1/sub-3855_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3857/1/sub-3857_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3863/1/sub-3863_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3866/1/sub-3866_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3870/1/sub-3870_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4001/1/sub-4001_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4004/1/sub-4004_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4005/1/sub-4005_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4010/1/sub-4010_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4012/1/sub-4012_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4013/1/sub-4013_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4018/1/sub-4018_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4019/1/sub-4019_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4020/1/sub-4020_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4021/1/sub-4021_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4022/1/sub-4022_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4024/1/sub-4024_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4025/1/sub-4025_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4026/1/sub-4026_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4027/1/sub-4027_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4029/1/sub-4029_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4030/1/sub-4030_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4032/1/sub-4032_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4033/1/sub-4033_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4034/1/sub-4034_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4035/1/sub-4035_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4037/1/sub-4037_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4038/1/sub-4038_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4065/1/sub-4065_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4067/1/sub-4067_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4081/1/sub-4081_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4082/1/sub-4082_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4083/1/sub-4083_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4085/1/sub-4085_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4135/1/sub-4135_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4136/1/sub-4136_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/4139/1/sub-4139_ses-1_run-01_T1w.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3900/1/PPMI_3900_MR_t1_mpr_ns_sag_p2_iso_br_raw_20130826143320430_111_S199208_I387390.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3905/1/PPMI_3905_MR_t1_mpr_ns_sag_p2_iso_br_raw_20121219100210466_145_S178154_I352265.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3916/1/PPMI_3916_MR_t1_mpr_ns_sag_p2_iso_br_raw_20130424114845043_116_S187851_I368600.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3914/1/PPMI_3914_MR_t1_mpr_ns_sag_p2_iso_br_raw_20130424114239261_57_S187848_I368597.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3917/1/PPMI_3917_MR_t1_mpr_ns_sag_p2_iso_br_raw_20130624090154374_71_S193069_I377730.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
# .Docker version 23.0.5, build bc4487a
# Sanity check failed for input/minc_from_nifti_reorient_minc/3901/1/PPMI_3901_MR_t1_mpr_ns_sag_p2_iso_br_raw_20121219093740852_166_S178146_I352257.mnc, trying to flip xdirection too.
# Docker version 23.0.5, build bc4487a
